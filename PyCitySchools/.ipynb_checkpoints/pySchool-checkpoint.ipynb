# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
school_data_to_load = "Resources_schools_complete.csv"
student_data_to_load = "Resources_students_complete.csv"

# Read School and Student Data File and store into Pandas Data Frames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])

# %%
student_data.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score
# 0             66          79
# 1             94          61
# 2             90          60
# 3             67          58
# 4             97          84

# %%
school_data_complete.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %%
school_data.head()
# Out:
#    School ID            school_name      type  size   budget
# 0          0      Huang High School  District  2917  1910635
# 1          1   Figueroa High School  District  2949  1884411
# 2          2    Shelton High School   Charter  1761  1056600
# 3          3  Hernandez High School  District  4635  3022020
# 4          4    Griffin High School   Charter  1468   917500

# %%
school_total=len(school_data.index)
school_total
# Out:
# 15

# %%
student_total=len(student_data.index)
student_total
# Out:
# 39170

# %%
total_budget=school_data["budget"].sum()

total_budget
# Out:
# 24649428

# %%
ave_math_score=school_data_complete["math_score"].mean()
ave_math_score
# Out:
# 78.98537145774827

# %%
ave_reading_score=school_data_complete["reading_score"].mean()
ave_reading_score
# Out:
# 81.87784018381414

# %%
students_passing_math=student_data["math_score"]>=70
percent_pass_math=((students_passing_math.sum())/(student_total))
percent_pass_math
# Out:
# 0.749808526933878

# %%
student_passing_reading=student_data["reading_score"]>=70
percent_pass_reading=((student_passing_reading.sum())/(student_total))
percent_pass_reading
# Out:
# 0.8580546336482001

# %%
overall_passing=(percent_pass_reading+percent_pass_math)/2


#This would be the correct way to calculate passing
#overall_passing=student_data[(student_data["math_score"] >= 70) & (student_data["reading_score"] >= 70)]["student_name"].count()/student_total

overall_passing
# Out:
# 0.8039315802910391

# %%
District_Summary=pd.DataFrame({"Total Schools":[school_total],
                             "Total Students":[student_total],
                             "Total Budget":[total_budget],
                             "Average Math Score":[ave_math_score],
                             "Average Reading Score":[ave_reading_score],
                             "% Passing Math":[percent_pass_math],
                             "% Passing Reading":[percent_pass_reading],
                             "Overall Passing Rate":[overall_passing]})
District_Summary
# Out:
#    Total Schools  Total Students  Total Budget  Average Math Score  \
# 0             15           39170      24649428           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  \
# 0               81.87784        0.749809           0.858055
#
#    Overall Passing Rate
# 0              0.803932

# %%
District_Sum=pd.DataFrame(District_Summary, columns=["Total Schools","Total Students","Total Budget","Average Math Score","Average Reading Score","% Passing Math", "% Passing Reading", "Overall Passing Rate"])

District_Sum.style.format({"Total Students":"{:,}",
                       "Total Budget": "${:,.2f}", 
                       "Average Reading Score": "{:.2f}", 
                       "Average Math Score": "{:.2f}", 
                       "% Passing Math": "{:.2%}", 
                       "% Passing Reading": "{:.2%}", 
                       "Overall Passing Rate": "{:.2%}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_82626298_1f74_11ea_a1d3_2839261bf8e8" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Schools</th>        <th class="col_heading level0 col1" >Total Students</th>        <th class="col_heading level0 col2" >Total Budget</th>        <th class="col_heading level0 col3" >Average Math Score</th>        <th class="col_heading level0 col4" >Average Reading Score</th>        <th class="col_heading level0 col5" >% Passing Math</th>        <th class="col_heading level0 col6" >% Passing Reading</th>        <th class="col_heading level0 col7" >Overall Passing Rate</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_82626298_1f74_11ea_a1d3_2839261bf8e8level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_82626298_1f74_11ea_a1d3_2839261bf8e8row0_col0" class="data row0 col0" >15</td>
# ...

# %%
school_data
# Out:
#     School ID            school_name      type  size   budget
# 0           0      Huang High School  District  2917  1910635
# 1           1   Figueroa High School  District  2949  1884411
# 2           2    Shelton High School   Charter  1761  1056600
# 3           3  Hernandez High School  District  4635  3022020
# 4           4    Griffin High School   Charter  1468   917500
# 5           5     Wilson High School   Charter  2283  1319574
# 6           6    Cabrera High School   Charter  1858  1081356
# 7           7     Bailey High School  District  4976  3124928
# 8           8     Holden High School   Charter   427   248087
# 9           9       Pena High School   Charter   962   585858
# 10         10     Wright High School   Charter  1800  1049400
# 11         11  Rodriguez High School  District  3999  2547363
# 12         12    Johnson High School  District  4761  3094650
# 13         13       Ford High School  District  2739  1763916
# ...

# %%
by_school = school_data_complete.set_index("school_name").groupby("school_name")
by_school.head()
# Out:
#                     Student ID       student_name gender grade  reading_score  \
# school_name
# Huang High School            0       Paul Bradley      M   9th             66
# Huang High School            1       Victor Smith      M  12th             94
# Huang High School            2    Kevin Rodriguez      M  12th             90
# Huang High School            3  Dr. Richard Scott      M  12th             67
# Huang High School            4         Bonnie Ray      F   9th             97
# ...                        ...                ...    ...   ...            ...
# Thomas High School       37535         Norma Mata      F  10th             76
# Thomas High School       37536        Cody Miller      M  11th             84
# Thomas High School       37537        Erik Snyder      M   9th             80
# Thomas High School       37538     Tanya Martinez      F   9th             71
# Thomas High School       37539      Noah Erickson      M   9th             86
#
# ...

# %%
school_types = school_data.set_index("school_name")["type"]
student_per_school = by_school["student_name"].count()
school_budget = school_data.set_index("school_name")["budget"]
per_student_budget = school_data.set_index("school_name")["budget"]/school_data.set_index("school_name")["size"]
ave_math_school = by_school["math_score"].mean()
ave_read_school = by_school["reading_score"].mean()
pass_math_school = school_data_complete[school_data_complete["math_score"] >= 70].groupby("school_name")["student_name"].count()/student_per_school 
pass_read_school = school_data_complete[school_data_complete["reading_score"] >= 70].groupby("school_name")["student_name"].count()/student_per_school 
overall_pass_school = (pass_math_school+pass_read_school)/2


#the correct way to judge passing %
#overall_pass_school = school_data_complete[(school_data_complete["reading_score"] >= 70) & (school_data_complete["math_score"] >= 70)].groupby("school_name")["student_name"].count()/student_per_school

school_summary = pd.DataFrame({
    "School Type": school_types,
    "Total Students": student_per_school,
    "Per Student Budget": per_student_budget,
    "Total School Budget": school_budget,
    "Average Math Score": ave_math_school,
    "Average Reading Score": ave_read_school,
    '% Passing Math': pass_math_school,
    '% Passing Reading': pass_read_school,
    "Overall Passing Rate": overall_pass_school})

school_summary = school_summary[['School Type', 
                          'Total Students', 
                          'Total School Budget', 
                          'Per Student Budget', 
                          'Average Math Score', 
                          'Average Reading Score',
                          '% Passing Math',
                          '% Passing Reading',
                          'Overall Passing Rate']]

school_summary.style.format({'Total Students': '{:,}', 
                          "Total School Budget": "${:,}", 
                          "Per Student Budget": "${:.2f}",
                          'Average Math Score': "{:.2f}", 
                          'Average Reading Score': "{:.2f}", 
                          "% Passing Math": "{:.2%}", 
                          "% Passing Reading": "{:.2%}", 
                          "Overall Passing Rate": "{:.2%}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_9e1810ee_1f74_11ea_b5c9_2839261bf8e8" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >School Type</th>        <th class="col_heading level0 col1" >Total Students</th>        <th class="col_heading level0 col2" >Total School Budget</th>        <th class="col_heading level0 col3" >Per Student Budget</th>        <th class="col_heading level0 col4" >Average Math Score</th>        <th class="col_heading level0 col5" >Average Reading Score</th>        <th class="col_heading level0 col6" >% Passing Math</th>        <th class="col_heading level0 col7" >% Passing Reading</th>        <th class="col_heading level0 col8" >Overall Passing Rate</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9e1810ee_1f74_11ea_b5c9_2839261bf8e8level0_row0" class="row_heading level0 row0" >Bailey High School</th>
# ...

# %%
top_five_schools = school_summary.sort_values("Overall Passing Rate", ascending = False)
top_five_schools.head().style.format({'Total Students': '{:,}', 
                          "Total School Budget": "${:,}", 
                          "Per Student Budget": "${:.2f}",
                          'Average Math Score': "{:.2f}", 
                          'Average Reading Score': "{:.2f}", 
                          "% Passing Math": "{:.2%}", 
                          "% Passing Reading": "{:.2%}", 
                          "Overall Passing Rate": "{:.2%}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_bfd25cc6_1f74_11ea_b0ab_2839261bf8e8" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >School Type</th>        <th class="col_heading level0 col1" >Total Students</th>        <th class="col_heading level0 col2" >Total School Budget</th>        <th class="col_heading level0 col3" >Per Student Budget</th>        <th class="col_heading level0 col4" >Average Math Score</th>        <th class="col_heading level0 col5" >Average Reading Score</th>        <th class="col_heading level0 col6" >% Passing Math</th>        <th class="col_heading level0 col7" >% Passing Reading</th>        <th class="col_heading level0 col8" >Overall Passing Rate</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_bfd25cc6_1f74_11ea_b0ab_2839261bf8e8level0_row0" class="row_heading level0 row0" >Cabrera High School</th>
# ...

# %%
bottom_five_schools = school_summary.sort_values("Overall Passing Rate", ascending = True)
bottom_five_schools.head().style.format({'Total Students': '{:,}', 
                          "Total School Budget": "${:,}", 
                          "Per Student Budget": "${:.2f}",
                          'Average Math Score': "{:.2f}", 
                          'Average Reading Score': "{:.2f}", 
                          "% Passing Math": "{:.2%}", 
                          "% Passing Reading": "{:.2%}", 
                          "Overall Passing Rate": "{:.2%}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_c1b8df92_1f74_11ea_81e3_2839261bf8e8" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >School Type</th>        <th class="col_heading level0 col1" >Total Students</th>        <th class="col_heading level0 col2" >Total School Budget</th>        <th class="col_heading level0 col3" >Per Student Budget</th>        <th class="col_heading level0 col4" >Average Math Score</th>        <th class="col_heading level0 col5" >Average Reading Score</th>        <th class="col_heading level0 col6" >% Passing Math</th>        <th class="col_heading level0 col7" >% Passing Reading</th>        <th class="col_heading level0 col8" >Overall Passing Rate</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c1b8df92_1f74_11ea_81e3_2839261bf8e8level0_row0" class="row_heading level0 row0" >Rodriguez High School</th>
# ...

# %%
ninth_math = student_data.loc[student_data["grade"] == "9th"].groupby("school_name")["math_score"].mean()
tenth_math = student_data.loc[student_data["grade"] == "10th"].groupby("school_name")["math_score"].mean()
eleventh_math = student_data.loc[student_data["grade"] == "11th"].groupby("school_name")["math_score"].mean()
twelfth_math = student_data.loc[student_data["grade"] == "12th"].groupby("school_name")["math_score"].mean()



math_scores_grade = pd.DataFrame({
        "9th": ninth_math,
        "10th": tenth_math,
        "11th": eleventh_math,
        "12th": twelfth_math
})
math_scores_grade = math_scores_grade[['9th', '10th', '11th', '12th']]
math_scores_grade.index.name = "School"

math_scores_grade.style.format({'9th': '{:.2f}', 
                          "10th": '{:.2f}', 
                          "11th": "{:.2f}", 
                          "12th": "{:.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_c41b6ffa_1f74_11ea_95b4_2839261bf8e8" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >9th</th>        <th class="col_heading level0 col1" >10th</th>        <th class="col_heading level0 col2" >11th</th>        <th class="col_heading level0 col3" >12th</th>    </tr>    <tr>        <th class="index_name level0" >School</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c41b6ffa_1f74_11ea_95b4_2839261bf8e8level0_row0" class="row_heading level0 row0" >Bailey High School</th>
#                         <td id="T_c41b6ffa_1f74_11ea_95b4_2839261bf8e8row0_col0" class="data row0 col0" >77.08</td>
#                         <td id="T_c41b6ffa_1f74_11ea_95b4_2839261bf8e8row0_col1" class="data row0 col1" >77.00</td>
# ...

# %%
ninth_read = student_data.loc[student_data["grade"] == "9th"].groupby("school_name")["reading_score"].mean()
tenth_read = student_data.loc[student_data["grade"] == "10th"].groupby("school_name")["reading_score"].mean()
eleventh_read = student_data.loc[student_data["grade"] == "11th"].groupby("school_name")["reading_score"].mean()
twelfth_read = student_data.loc[student_data["grade"] == "12th"].groupby("school_name")["reading_score"].mean()



read_scores_grade = pd.DataFrame({
        "9th": ninth_read,
        "10th": tenth_read,
        "11th": eleventh_read,
        "12th": twelfth_read
})
read_scores_grade = read_scores_grade[['9th', '10th', '11th', '12th']]
read_scores_grade.index.name = "School"

read_scores_grade.style.format({'9th': '{:.2f}', 
                          "10th": '{:.2f}', 
                          "11th": "{:.2f}", 
                          "12th": "{:.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_c61e8df6_1f74_11ea_975b_2839261bf8e8" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >9th</th>        <th class="col_heading level0 col1" >10th</th>        <th class="col_heading level0 col2" >11th</th>        <th class="col_heading level0 col3" >12th</th>    </tr>    <tr>        <th class="index_name level0" >School</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c61e8df6_1f74_11ea_975b_2839261bf8e8level0_row0" class="row_heading level0 row0" >Bailey High School</th>
#                         <td id="T_c61e8df6_1f74_11ea_975b_2839261bf8e8row0_col0" class="data row0 col0" >81.30</td>
#                         <td id="T_c61e8df6_1f74_11ea_975b_2839261bf8e8row0_col1" class="data row0 col1" >80.91</td>
# ...

# %%
bins = [0, 584.999, 614.999, 644.999, 999999]
group_name = ["<$585", "$585-615", "$615-645", "$645-675"]
school_data_complete['spending_bins'] = pd.cut(school_data_complete['budget']/school_data_complete['size'], bins, labels = group_name)

by_spending = school_data_complete.groupby('spending_bins')

avg_math = by_spending['math_score'].mean()
avg_read = by_spending['reading_score'].mean()
pass_math = school_data_complete[school_data_complete['math_score'] >= 70].groupby('spending_bins')['student_name'].count()/by_spending['Student ID'].count()
pass_read = school_data_complete[school_data_complete['reading_score'] >= 70].groupby('spending_bins')['student_name'].count()/by_spending['Student ID'].count()
overall = (pass_math+pass_read)/2

scores_by_spend = pd.DataFrame({
    "Average Math Score": avg_math,
    "Average Reading Score": avg_read,
    '% Passing Math': pass_math,
    '% Passing Reading': pass_read,
    "Overall Passing Rate": overall})
    
scores_by_spend = scores_by_spend[[
    "Average Math Score",
    "Average Reading Score",
    '% Passing Math',
    '% Passing Reading',
    "Overall Passing Rate"]]  
    
scores_by_spend.index.name = "Spending Ranges (per student)"
scores_by_spend = scores_by_spend.reindex(group_name)

scores_by_spend.style.format({'Average Math Score': '{:.2f}', 
                              'Average Reading Score': '{:.2f}', 
                              '% Passing Math': '{:.2%}', 
                              '% Passing Reading':'{:.2%}', 
                              'Overall Passing Rate': '{:.2%}'})
# Out:
# <style  type="text/css" >
# </style><table id="T_70ffa74c_1f71_11ea_bd16_2839261bf8e8" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Average Math Score</th>        <th class="col_heading level0 col1" >Average Reading Score</th>        <th class="col_heading level0 col2" >% Passing Math</th>        <th class="col_heading level0 col3" >% Passing Reading</th>        <th class="col_heading level0 col4" >Overall Passing Rate</th>    </tr>    <tr>        <th class="index_name level0" >Spending Ranges (per student)</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_70ffa74c_1f71_11ea_bd16_2839261bf8e8level0_row0" class="row_heading level0 row0" ><$585</th>
# ...

# %%
bins = [0, 999, 1999, 5000]
group_name = ["Small (<1000)", "Medium (1000-2000)", "Large (2000-5000)"]

school_data_complete['size_bins'] = pd.cut(school_data_complete['size'], bins=bins, labels = group_name)

by_size = school_data_complete.groupby('size_bins')


avg_math_size = by_size['math_score'].mean()
avg_read_size = by_size['math_score'].mean()
pass_math_size = school_data_complete[school_data_complete['math_score'] >= 70].groupby('size_bins')['Student ID'].count()/by_size['Student ID'].count()
pass_read_size = school_data_complete[school_data_complete['reading_score'] >= 70].groupby('size_bins')['Student ID'].count()/by_size['Student ID'].count()
overall_size = ((pass_math_size)+(pass_read_size))/2

scores_by_size = pd.DataFrame({
    "Average Math Score": avg_math_size,
    "Average Reading Score": avg_read_size,
    '% Passing Math': pass_math_size,
    '% Passing Reading': pass_read_size,
    "Overall Passing Rate": overall_size})
    
scores_by_size = scores_by_size[[
    "Average Math Score",
    "Average Reading Score",
    '% Passing Math',
    '% Passing Reading',
    "Overall Passing Rate"]]  
    
scores_by_size.index.name = "Size Ranges (# of students)"

scores_by_size = scores_by_size.reindex(group_name)


scores_by_size.style.format({'Average Math Score': '{:.2f}', 
                              'Average Reading Score': '{:.2f}', 
                              '% Passing Math': '{:.2%}', 
                              '% Passing Reading':'{:.2%}', 
                              'Overall Passing Rate': '{:.2%}'})
# Out:
# <style  type="text/css" >
# </style><table id="T_26875248_1f75_11ea_a144_2839261bf8e8" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Average Math Score</th>        <th class="col_heading level0 col1" >Average Reading Score</th>        <th class="col_heading level0 col2" >% Passing Math</th>        <th class="col_heading level0 col3" >% Passing Reading</th>        <th class="col_heading level0 col4" >Overall Passing Rate</th>    </tr>    <tr>        <th class="index_name level0" >Size Ranges (# of students)</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_26875248_1f75_11ea_a144_2839261bf8e8level0_row0" class="row_heading level0 row0" >Small (<1000)</th>
# ...

# %%
by_type = school_data_complete.groupby("type")

 
avg_math_type = by_type['math_score'].mean()
avg_read_type = by_type['math_score'].mean()
pass_math_type = school_data_complete[school_data_complete['math_score'] >= 70].groupby('type')['Student ID'].count()/by_type['Student ID'].count()
pass_read_type = school_data_complete[school_data_complete['reading_score'] >= 70].groupby('type')['Student ID'].count()/by_type['Student ID'].count()
overall_type = (pass_math_type+pass_read_type)/2
           
scores_by_type = pd.DataFrame({
    "Average Math Score": avg_math_type,
    "Average Reading Score": avg_read_type,
    '% Passing Math': pass_math_type,
    '% Passing Reading': pass_read_type,
    "Overall Passing Rate": overall_type})
    

scores_by_type = scores_by_type[[
    "Average Math Score",
    "Average Reading Score",
    '% Passing Math',
    '% Passing Reading',
    "Overall Passing Rate"
]]
scores_by_type.index.name = "Type of School"



scores_by_type.style.format({'Average Math Score': '{:.2f}', 
                              'Average Reading Score': '{:.2f}', 
                              '% Passing Math': '{:.2%}', 
                              '% Passing Reading':'{:.2%}', 
                              'Overall Passing Rate': '{:.2%}'})
# Out:
# <style  type="text/css" >
# </style><table id="T_fe66b086_1f75_11ea_946b_2839261bf8e8" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Average Math Score</th>        <th class="col_heading level0 col1" >Average Reading Score</th>        <th class="col_heading level0 col2" >% Passing Math</th>        <th class="col_heading level0 col3" >% Passing Reading</th>        <th class="col_heading level0 col4" >Overall Passing Rate</th>    </tr>    <tr>        <th class="index_name level0" >Type of School</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fe66b086_1f75_11ea_946b_2839261bf8e8level0_row0" class="row_heading level0 row0" >Charter</th>
# ...
